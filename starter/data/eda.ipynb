# %%
# !pip install pandas_profiling
# Out:
# Requirement already satisfied: pandas_profiling in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: markupsafe~=2.0.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (2.0.1)
# Requirement already satisfied: missingno>=0.4.2 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (0.5.0)
# Requirement already satisfied: htmlmin>=0.1.12 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: phik>=0.11.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (0.12.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (1.3.4)
# Requirement already satisfied: scipy>=1.4.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (1.7.1)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (0.1.0)
# Requirement already satisfied: seaborn>=0.10.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: PyYAML>=5.0.0 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: requests>=2.24.0 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (2.25.1)
# Requirement already satisfied: tqdm>=4.48.2 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (4.62.3)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: matplotlib>=3.2.0 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (3.4.3)
# Requirement already satisfied: multimethod>=1.4 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (1.6)
# Requirement already satisfied: numpy>=1.16.0 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (1.21.3)
# Requirement already satisfied: jinja2>=2.11.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (3.0.2)
# Requirement already satisfied: joblib~=1.0.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (1.0.1)
# Requirement already satisfied: pydantic>=1.8.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas_profiling) (1.8.2)
# Requirement already satisfied: attrs>=19.3.0 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.2.0)
# Requirement already satisfied: networkx>=2.4 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (2.5)
# Requirement already satisfied: imagehash in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.2.1)
# Requirement already satisfied: Pillow in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from pydantic>=1.8.1->pandas_profiling) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from requests>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from requests>=2.24.0->pandas_profiling) (1.26.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from requests>=2.24.0->pandas_profiling) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from requests>=2.24.0->pandas_profiling) (2.10)
# Requirement already satisfied: six in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas_profiling) (1.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from networkx>=2.4->visions[type_image_path]==0.7.4->pandas_profiling) (5.1.0)
# Requirement already satisfied: PyWavelets in /home/mqueyrel/anaconda3/envs/project_3/lib/python3.8/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.1.1)

# %%
import pandas as pd
import pandas_profiling

# %%
df = pd.read_csv("census.csv")
profile = pandas_profiling.ProfileReport(df)
profile
# Out:
#        age          workclass   fnlgt    education   education-num  \
# 0       39          State-gov   77516    Bachelors              13
# 1       50   Self-emp-not-inc   83311    Bachelors              13
# 2       38            Private  215646      HS-grad               9
# 3       53            Private  234721         11th               7
# 4       28            Private  338409    Bachelors              13
# ...    ...                ...     ...          ...             ...
# 32556   27            Private  257302   Assoc-acdm              12
# 32557   40            Private  154374      HS-grad               9
# 32558   58            Private  151910      HS-grad               9
# 32559   22            Private  201490      HS-grad               9
# 32560   52       Self-emp-inc  287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country  \
# 0         Male           2174              0               40   United-States
# 1         Male              0              0               13   United-States
# 2         Male              0              0               40   United-States
# 3         Male              0              0               40   United-States
# 4       Female              0              0               40            Cuba
# ...        ...            ...            ...              ...             ...
# 32556   Female              0              0               38   United-States
# 32557     Male              0              0               40   United-States
# 32558   Female              0              0               40   United-States
# 32559     Male              0              0               20   United-States
# 32560   Female          15024              0               40   United-States
#
#        salary
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]
